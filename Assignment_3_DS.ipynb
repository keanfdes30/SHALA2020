# %% [markdown]
# <a href="https://colab.research.google.com/github/keanfdes30/SHALA2020/blob/master/DS_L3_20_April_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.head(10)
# Out:
#    Unnamed: 0                   title  ...            actor4                actor5
# 0           1             Filly Brown  ...     Emilio Rivera   Joseph Julian Soria
# 1           2                The Dish  ...          Tom Long        Genevieve Mooy
# 2           3     Waiting for Guffman  ...       Eugene Levy           Bob Balaban
# 3           4    The Age of Innocence  ...  Richard E. Grant          Alec McCowen
# 4           5             Malevolence  ...     Heather Magee        Richard Glover
# 5           6             Old Partner  ...               NaN                   NaN
# 6           7               Lady Jane  ...   Jill Bennett II  Helena Bonham Carter
# 7           8            Mad Dog Time  ...      Ellen Barkin            Diane Lane
# 8           9  Beauty Is Embarrassing  ...   Jonathan Dayton        Cliff Benjamin
# 9          10    The Snowtown Murders  ...       Craig Coyne         Richard Green
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
# Draw the heatmap 
plt.figure(figsize=(19,15))
plt.matshow(movies.corr(),fignum=1)
plt.xticks(ticks = range(1,12),labels = movies.corr().index)
plt.yticks(ticks = range(1,12),labels = movies.corr().index)
temp = np.array(movies.corr())
for i in range(1,12):
  for j in range(1,12):
    plt.text(i,j,f"{temp[i-1][j-1]:.3f}",ha="center",va="center")

# %%
# Creating a mask for removing duplicates 
mask = np.zeros_like(movies.corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(15,19))
sns.heatmap(movies.corr(),annot=True,mask=mask)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
#@title Default title text
# Draw a histogram 
train.hist(figsize=(20,20))
# Find out the redundant features 
# EmployeeCount,ID,EmployeeNumber are relatively redundant
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f937f1c11d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937f2d0320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937f0573c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937f077748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937f025ac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f937efd7e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ef96208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937efc7550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937efc75c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ef2cc88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f937eedffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ee9c3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937eecc748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ee80ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ee32e48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f937edf1208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937eda3588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ed54908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ed88c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ed3bfd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f937ecfa3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ecac748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ec5cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ec90e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ec4d208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f937ec00588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f937ebb0908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f938205b748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9380194080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f93805f6cc0>]],
#       dtype=object)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
sns.regplot(movies.imdb_rating,movies.audience_score)

# %%
# Change marker of the scatter plot
plt.figure(figsize=(10,8))
sns.regplot(movies.imdb_rating,movies.audience_score,line_kws={"color":"red"},scatter_kws={"alpha":0.5,"s":200})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
print(df.head(2))
 
# Use the 'hue' argument to provide a factor variable
sns.scatterplot('petal_length','petal_width',hue='species',data=df)
 
# Move the legend to an empty part of the plot
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
from matplotlib.pyplot import subplot
df = sns.load_dataset('iris')
plt.figure(figsize=(8,8))
subplot(2,2,1)
sns.distplot(df['sepal_width'],hist=False,kde_kws={"shade":True})
subplot(2,2,2)
sns.distplot(df['sepal_length'],hist=False,kde_kws={"shade":True})
subplot(2,2,3)
sns.distplot(df['petal_width'],hist=False,kde_kws={"shade":True})
subplot(2,2,4)
sns.distplot(df['petal_length'],hist=False,kde_kws={"shade":True})

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
sns.violinplot('species','sepal_length',data=df)

# %%
# Change the color of each group 

sns.violinplot('species','sepal_length',data=df,palette={"versicolor":"green","setosa":"blue","virginica":"m"})
